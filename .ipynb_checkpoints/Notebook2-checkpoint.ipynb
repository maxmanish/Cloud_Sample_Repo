# %%
print ("welcome to Jupyter notebooks v5")
# Out:
# welcome to Jupyter notebooks v5

# %%
a=5
b=10
c=a+b
print ("hello", c+10)
# Out:
# hello 25

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.4.4'

# %%
a1d = np.array([1,2,3,4,5,6])
a1d
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
print(a1d)
print(type(a1d))
# Out:
# [1 2 3 4 5 6]
# <class 'numpy.ndarray'>

# %%
print(a1d.shape)
print(a1d.size)
data = [
    {"Name": "Amit", "Age": 25}
]
print(data)
# Out:
# (6,)
# 6
# [{'Name': 'Amit', 'Age': 25}]

# %%
import pandas as pd
df = pd.DataFrame(data)
df.head()
# Out:
#    Name  Age
# 0  Amit   25
